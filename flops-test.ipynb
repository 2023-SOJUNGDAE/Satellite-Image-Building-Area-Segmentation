# %%
import torch
from ptflops import get_model_complexity_info

import segmentation_models_pytorch as smp
from transformers import AutoImageProcessor, UperNetForSemanticSegmentation
from backbones_unet.model.unet import Unet

with torch.cuda.device(0):
    # net = Unet(
    # 	backbone='convnext_xlarge_in22ft1k',
    # 	in_channels=3,
    # 	num_classes=1,
	# )
    net = UperNetForSemanticSegmentation.from_pretrained("openmmlab/upernet-convnext-large", num_labels=1, ignore_mismatched_sizes=True)

macs, params = get_model_complexity_info(net, (3, 224, 224), as_strings=True,print_per_layer_stat=True, verbose=True)
print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# ...
# Unet(
#   357.03 M, 99.969% Params, 64.76 GMac, 100.000% MACs,
#   (encoder): FeatureListNet(
#     348.03 M, 97.450% Params, 60.93 GMac, 94.093% MACs,
#     (stem_0): Conv2d(12.54 k, 0.004% Params, 39.34 MMac, 0.061% MACs, 3, 256, kernel_size=(4, 4), stride=(4, 4))
#     (stem_1): LayerNorm2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (256,), eps=1e-06, elementwise_affine=True)
#     (stages_0): ConvNeXtStage(
#       1.62 M, 0.452% Params, 5.05 GMac, 7.803% MACs,
#       (downsample): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (blocks): Sequential(
#         1.62 M, 0.452% Params, 5.05 GMac, 7.803% MACs,
#         (0): ConvNeXtBlock(
#           538.37 k, 0.151% Params, 1.68 GMac, 2.601% MACs,
#           (conv_dw): Conv2d(12.8 k, 0.004% Params, 40.14 MMac, 0.062% MACs, 256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#           (norm): LayerNorm(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (256,), eps=1e-06, elementwise_affine=True)
# ...
